# %% [markdown]
# # Drugs Sales Report

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\acer.DESKTOP-1VQGBE7\OneDrive\Desktop\Druge_dataset.xls.csv")
df
# Out:
#                                              drug_name medical_condition  \
# 0                                          doxycycline              Acne
# 1                                       spironolactone              Acne
# 2                                            Aldactone              Acne
# 3                                         isotretinoin              Acne
# 4                                            Acticlate              Acne
# ..                                                 ...               ...
# 246  hyoscyamine / methenamine / methylene blue / p...               UTI
# 247                                         Phosphasal               UTI
# 248                                    phendimetrazine       Weight Loss
# 249                                            Lomaira       Weight Loss
# 250                                      benzphetamine       Weight Loss
#
#                                           side_effects  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   drug_name                      251 non-null    object
#  1   medical_condition              251 non-null    object
#  2   side_effects                   251 non-null    object
#  3   generic_name                   251 non-null    object
#  4   drug_classes                   251 non-null    object
#  5   brand_names                    251 non-null    object
#  6   activity                       251 non-null    object
#  7   rx_otc                         251 non-null    object
#  8   pregnancy_category             251 non-null    object
#  9   csa                            251 non-null    object
#  10  alcohol                        251 non-null    object
#  11  related_drugs                  251 non-null    object
# ...

# %%
df.head(10)
# Out:
#                           drug_name medical_condition  \
# 0                       doxycycline              Acne
# 1                    spironolactone              Acne
# 2                         Aldactone              Acne
# 3                      isotretinoin              Acne
# 4                         Acticlate              Acne
# 5   sulfamethoxazole / trimethoprim              Acne
# 6                             Adoxa              Acne
# 7                          Claravis              Acne
# 8                          Myorisan              Acne
# 9  drospirenone / ethinyl estradiol              Acne
#
#                                         side_effects  \
# 0  (hives, difficult breathing, swelling in your ...
# 1  hives ; difficulty breathing; swelling of your...
# 2  hives ; difficulty breathing; swelling of your...
# 3  problems with your vision or hearing; muscle o...
# 4  WARNING/CAUTION: Even though it may be rare, s...
# ...

# %%
df.drop_duplicates()
# Out:
#                                              drug_name medical_condition  \
# 0                                          doxycycline              Acne
# 1                                       spironolactone              Acne
# 2                                            Aldactone              Acne
# 3                                         isotretinoin              Acne
# 4                                            Acticlate              Acne
# ..                                                 ...               ...
# 246  hyoscyamine / methenamine / methylene blue / p...               UTI
# 247                                         Phosphasal               UTI
# 248                                    phendimetrazine       Weight Loss
# 249                                            Lomaira       Weight Loss
# 250                                      benzphetamine       Weight Loss
#
#                                           side_effects  \
# ...

# %%
df = df.drop('Unnamed: 17',axis = 1)
df = df.drop('Unnamed: 18',axis = 1)
df
# Out:
#                                              drug_name medical_condition  \
# 0                                          doxycycline              Acne
# 1                                       spironolactone              Acne
# 2                                            Aldactone              Acne
# 3                                         isotretinoin              Acne
# 4                                            Acticlate              Acne
# ..                                                 ...               ...
# 246  hyoscyamine / methenamine / methylene blue / p...               UTI
# 247                                         Phosphasal               UTI
# 248                                    phendimetrazine       Weight Loss
# 249                                            Lomaira       Weight Loss
# 250                                      benzphetamine       Weight Loss
#
#                                           side_effects  \
# ...

# %%
df.isnull().sum()
# Out:
# drug_name                        0
# medical_condition                0
# side_effects                     0
# generic_name                     0
# drug_classes                     0
# brand_names                      0
# activity                         0
# rx_otc                           0
# pregnancy_category               0
# csa                              0
# alcohol                          0
# related_drugs                    0
# medical_condition_description    0
# rating                           0
# no_of_reviews                    0
# drug_link                        0
# medical_condition_url            0
# dtype: int64

# %%
df.sort_values(by = 'rating',ascending = False).head(10)
# Out:
#                                              drug_name  medical_condition  \
# 195  acetaminophen / aspirin / caffeine / salicylamide           Migraine
# 179                                           quazepam           Insomnia
# 229                         Doans Pills Extra Strength               Pain
# 86                                           amoxapine         Depression
# 26                                           ProCentra               ADHD
# 237                                       thioridazine      Schizophrenia
# 228                   aspirin / carisoprodol / codeine               Pain
# 108                 insulin isophane / insulin regular  Diabetes (Type 1)
# 42                                            tramadol            Anxiety
# 49                                          nefazodone            Anxiety
#
#                                           side_effects  \
# 195  WARNING/CAUTION: Even though it may be rare, s...
# ...

# %%
df.groupby('medical_condition').agg({'drug_name':['count']})
# Out:
#                      drug_name
#                          count
# medical_condition
# ADHD                        13
# AIDS/HIV                     1
# Acne                        17
# Allergies                    1
# Angina                       3
# Anxiety                     15
# Bipolar Disorder            14
# Bronchitis                   1
# Cancer                       1
# Cholesterol                  2
# Colds & Flu                 14
# Covid 19                     1
# Depression                  10
# Diabetes (Type 1)           20
# Diabetes (Type 2)           23
# Erectile Dysfunction         4
# GERD (Heartburn)             1
# Hayfever                     7
# Hypertension                20
# Incontinence                 6
# Insomnia                    16
# Migraine                    10
# Osteoarthritis               9
# Pain                        24
# Psoriasis                    1
# Schizophrenia                5
# Seizures                     3
# ...

# %%
df.groupby('medical_condition').agg({'no_of_reviews':['sum','max','min','count'],'rating':['sum','max','min','count']})
# Out:
#                      no_of_reviews                      rating              \
#                                sum     max    min count    sum   max   min
# medical_condition
# ADHD                        2227.0   833.0    2.0    13   98.3  10.0   5.5
# AIDS/HIV                       7.0     7.0    7.0     1    5.1   5.1   5.1
# Acne                        3532.0   999.0    1.0    17  113.5   8.8   2.6
# Allergies                    213.0   213.0  213.0     1    4.7   4.7   4.7
# Angina                         4.0     2.0    1.0     3   19.0  10.0   0.0
# Anxiety                     4078.0   840.0    1.0    15  120.4  10.0   6.0
# Bipolar Disorder            2595.0   681.0    2.0    14  102.1  10.0   5.6
# Bronchitis                     4.0     4.0    4.0     1    7.5   7.5   7.5
# Cholesterol                  175.0   115.0   60.0     2    9.0   4.7   4.3
# Colds & Flu                   46.0    16.0    1.0    14   76.3  10.0   0.0
# ...

# %%
df[df['pregnancy_category'].isin(['D','C'])]
# Out:
#                                              drug_name medical_condition  \
# 0                                          doxycycline              Acne
# 1                                       spironolactone              Acne
# 2                                            Aldactone              Acne
# 4                                            Acticlate              Acne
# 5                      sulfamethoxazole / trimethoprim              Acne
# ..                                                 ...               ...
# 244                                             Urelle               UTI
# 245                                      Urogesic Blue               UTI
# 246  hyoscyamine / methenamine / methylene blue / p...               UTI
# 247                                         Phosphasal               UTI
# 248                                    phendimetrazine       Weight Loss
#
#                                           side_effects  \
# ...

# %%
df['no_of_reviews'] = pd.to_numeric(df['no_of_reviews'],errors = 'coerce')

# %%
df.groupby('medical_condition').agg({'rating':['max','min']})
# Out:
#                      rating
#                         max   min
# medical_condition
# ADHD                   10.0   5.5
# AIDS/HIV                5.1   5.1
# Acne                    8.8   2.6
# Allergies               4.7   4.7
# Angina                 10.0   0.0
# Anxiety                10.0   6.0
# Bipolar Disorder       10.0   5.6
# Bronchitis              7.5   7.5
# Cancer                  NaN   NaN
# Cholesterol             4.7   4.3
# Colds & Flu            10.0   0.0
# Covid 19                7.8   7.8
# Depression              9.6   4.9
# Diabetes (Type 1)      10.0   0.0
# Diabetes (Type 2)       9.0   1.0
# Erectile Dysfunction    8.7   8.0
# GERD (Heartburn)        7.5   7.5
# Hayfever               10.0   5.0
# Hypertension           10.0   0.0
# Incontinence            8.0   2.0
# Insomnia               10.0   3.7
# Migraine                9.9   6.0
# Osteoarthritis          8.0   4.8
# Pain                    9.7   3.3
# Psoriasis               5.6   5.6
# ...

# %%
df.set_index('pregnancy_category', inplace = True)
df
# Out:
#                                                             drug_name  \
# pregnancy_category
# D                                                         doxycycline
# C                                                      spironolactone
# C                                                           Aldactone
# X                                                        isotretinoin
# D                                                           Acticlate
# ...                                                               ...
# C                   hyoscyamine / methenamine / methylene blue / p...
# C                                                          Phosphasal
# C                                                     phendimetrazine
# X                                                             Lomaira
# X                                                       benzphetamine
#
#                    medical_condition  \
# pregnancy_category
# D                               Acne
# ...

# %%
df.groupby('pregnancy_category').agg({'no_of_reviews':['sum']}).plot(kind = 'pie', y = 'no_of_reviews',figsize = (7,7))
# Out:
# <Axes: ylabel='sum'>

# %%
df.groupby('medical_condition').agg({'rating':['mean']}).plot(kind = 'bar',xlabel = 'Medical Condition', ylabel = 'Average Rating', figsize = (15,5))
# Out:
# <Axes: xlabel='Medical Condition', ylabel='Average Rating'>

# %%
df.plot.area(subplots = True)
# Out:
# array([<Axes: xlabel='pregnancy_category'>,
#        <Axes: xlabel='pregnancy_category'>], dtype=object)
